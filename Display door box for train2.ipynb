# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt

train1_path="/home/hacaton_irkutsk/train/train2"
img = cv2.imread(f"{train1_path}/out1.png", cv2.IMREAD_UNCHANGED)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
newsize = (1920,1080)
  
# resize image
resized = cv2.resize(img, newsize, interpolation = cv2.INTER_AREA)
crop = resized[300:1050,100:1350]


fig = plt.figure(figsize=(10, 10))
plt.imshow(crop)
plt.show()

# %%
import pandas as pd

door_df = pd.read_csv('door_coord_df2_single.csv')
door_df.head()
# Out:
#    door  xmin  ymin  xmax  ymax
# 0     1   182   652   311   905
# 1     1   172   646   368   975
# 2     1   179   649   338   907
# 3     1   207   663   354   915
# 4     1   238   680   373   909

# %%
fig = plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.show()

# %%
import numpy as np
door1_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=1:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door1_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door1_img)
plt.show()

# %%
import numpy as np
door2_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=2:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door2_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door2_img)
plt.show()

# %%
import numpy as np
door3_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=3:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door3_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door3_img)
plt.show()

# %%
import numpy as np
door4_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=4:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door4_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door4_img)
plt.show()

# %%
import numpy as np
door5_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=5:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door5_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door5_img)
plt.show()

# %%
import numpy as np
door6_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=6:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door6_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door6_img)
plt.show()

# %%
import numpy as np
door7_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=7:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door7_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door7_img)
plt.show()

# %%
import numpy as np
door8_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=8:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door8_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door8_img)
plt.show()

# %%
import numpy as np
door9_img = np.copy(resized)
for ind in door_df.index:
    door=door_df['door'][ind]
    if door!=9:
        continue
    xmin=door_df['xmin'][ind]
    ymin=door_df['ymin'][ind]
    xmax=door_df['xmax'][ind]
    ymax=door_df['ymax'][ind]
    
    cv2.rectangle(door9_img, (xmin, ymin), (xmax, ymax), (255,0,0), 2)
fig = plt.figure(figsize=(10, 10))
plt.imshow(door9_img)
plt.show()
